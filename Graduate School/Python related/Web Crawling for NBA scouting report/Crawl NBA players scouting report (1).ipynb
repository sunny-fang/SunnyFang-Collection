# %% [markdown]
# ### website: http://www.draftexpress.com/nba-mock-history/2019/all/all/

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import datetime
import dateutil.parser as parser
from tqdm import tqdm
from selenium.webdriver.support.ui import Select

# %%
draft_data = pd.read_csv('nba_draft_combine_all_years.csv')
playerlist = draft_data.iloc[:,1]
yearlist = draft_data.iloc[:,2]

# %%
draft_date_2009 = parser.parse('25 JUN, 2009')
draft_date_2010 = parser.parse('24 JUN, 2010')
draft_date_2011 = parser.parse('24 JUN, 2011')
draft_date_2012 = parser.parse('29 JUN, 2012')
draft_date_2013 = parser.parse('27 JUN, 2013')
draft_date_2014 = parser.parse('29 JUN, 2014')
draft_date_2015 = parser.parse('26 JUN, 2015')
draft_date_2016 = parser.parse('23 JUN, 2016')
draft_date_2017 = parser.parse('22 JUN, 2017')
dictionary = {'2009': draft_date_2009,'2010': draft_date_2010,'2011': draft_date_2011,'2012': draft_date_2012,'2013': draft_date_2013,
             '2014': draft_date_2014,'2015': draft_date_2015,'2016': draft_date_2016,'2017': draft_date_2017,}

# %%
for player, year in tqdm(zip(playerlist,yearlist)):
    print(player,year)
# Out:
# 0it [00:00, ?it/s]
# Blake Griffin 2009
# Terrence Williams 2009
# Gerald Henderson 2009
# Tyler Hansbrough 2009
# Earl Clark 2009
# Austin Daye 2009
# James Johnson 2009
# Jrue Holiday 2009
# Ty Lawson 2009
# Jeff Teague 2009
# Hasheem Thabeet 2009
# Eric Maynor 2009
# Darren Collison 2009
# Omri Casspi 2009
# Byron Mullens 2009
# Damion James 2009
# Rodrigue Beaubois 2009
# Taj Gibson 2009
# DeMarre Carroll 2009
# Greivis Vasquez 2009
# Wayne Ellington 2009
# Toney Douglas 2009
# James Harden 2009
# Jeff Pendergraph 2009
# Jermaine Taylor 2009
# Dante Cunningham 2009
# DaJuan Summers 2009
# 27it [00:00, 266.12it/s]
# Sam Young 2009
# DeJuan Blair 2009
# Tyreke Evans 2009
# Derrick Brown 2009
# Jodie Meeks 2009
# Marcus Thornton 2009
# Chase Budinger 2009
# Danny Green 2009
# Gani Lawal 2009
# Jack McClinton 2009
# A.J. Price 2009
# Luke Harangody 2009
# Patrick Mills 2009
# Jonny Flynn 2009
# Stephen Curry 2009
# Jordan Hill 2009
# Demar DeRozan 2009
# Dionte Christmas 2009
# Jeff Adrien 2009
# Jerel McNeal 2009
# Joe Ingles 2009
# Josh Heytvelt 2009
# Tyler Smith 2009
# John Wall 2010
# Paul George 2010
# Cole Aldrich 2010
# Xavier Henry 2010
# Ed Davis 2010
# Patrick Patterson 2010
# Larry Sanders 2010
# Luke Babbitt 2010
# Eric Bledsoe 2010
# Avery Bradley 2010
# Evan Turner 2010
# James Anderson 2010
# Craig Brackins 2010
# Trevor Booker 2010
# Dominique Jones 2010
# Jordan Crawford 2010
# Daniel Orton 2010
# Derrick Favors 2010
# Lazar Hayward 2010
# Dexter Pittman 2010
# Omer Yurtseven 2017
# P.J. Dozier 2017
# Peter Jok 2017
# Rawle Alkins 2017
# Sviatoslav Mykhailiuk 2017
# Thomas Welsh 2017
# V.J. Beachem 2017
# 517it [00:01, 401.76it/s]

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get('http://www.draftexpress.com/nba-mock-history/2019/all/all/')
player_name=[];title=[];date=[];early_than_draft_day=[];context=[]
for player, year in tqdm(zip(playerlist,yearlist),total=len(playerlist)):
    select = Select(driver.find_element_by_name('draft_history_filter[year]'))
    select.select_by_visible_text(str(year))
    driver.find_element_by_xpath("//*[@class='submit button']").click()
    element = driver.find_element_by_link_text(str(player))
    driver.execute_script("arguments[0].click();", element)
    testsoup = BeautifulSoup(driver.page_source, "html.parser")
    aa = testsoup.findAll('div',{'class':'article-details'})
    for index, row in enumerate(aa):
        player_name.append(player)
        title.append(aa[index].find_next('a').text.strip())
        time = aa[index].find_next('div',{'class':'small-12 medium-12 large-4 column end date'}).text.strip()
        date.append(time)
        early_than_draft_day.append(parser.parse(time) < dictionary[str(year)])
        context.append(aa[index].find('div',{'class':'article-content'}).text.strip())
    driver.back()

driver.close()

df = pd.DataFrame({'player_name':player_name,'title':title,'date':date,'early_than_draft_day':early_than_draft_day,'context':context})
df
# Out:
#   0%|                                                                                          | 0/517 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|▏                                                                               | 1/517 [00:41<5:55:31, 41.34s/it]
#
#
#
#
#
#   0%|▎                                                                               | 2/517 [00:48<4:26:48, 31.08s/it]
#
#
#
#
#
#   1%|▍                                                                               | 3/517 [00:53<3:20:03, 23.35s/it]
#
#
#
#
#
#   1%|▌                                                                               | 4/517 [01:00<2:37:39, 18.44s/it]
#
#
#
#
#
#   1%|▊                                                                               | 5/517 [01:08<2:08:48, 15.10s/it]
#
#
#
#
#
#   1%|▉                                                                               | 6/517 [01:15<1:47:59, 12.68s/it]
#
#
#
#
#
#   1%|█                                                                               | 7/517 [01:22<1:33:24, 10.99s/it]
#
#
#
#
#
#   2%|█▏                                                                              | 8/517 [01:30<1:25:43, 10.11s/it]
#
#
#
#
#
#   2%|█▍                                                                              | 9/517 [01:36<1:16:15,  9.01s/it]
#
#
#
#
#
#   2%|█▌                                                                             | 10/517 [01:42<1:08:18,  8.08s/it]
#
#
#
#
#
#   2%|█▋                                                                             | 11/517 [01:49<1:04:52,  7.69s/it]
#
#
#
#
#
#   2%|█▊                                                                             | 12/517 [01:55<1:01:39,  7.33s/it]
#
#
#
#
#
#   3%|█▉                                                                             | 13/517 [02:03<1:01:22,  7.31s/it]
#
#
#
#
#
#   3%|██▏                                                                              | 14/517 [02:09<59:41,  7.12s/it]
#
#
#
#
#
#   3%|██▎                                                                              | 15/517 [02:15<56:39,  6.77s/it]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-36-47dc08981166> in <module>
#       7     select.select_by_visible_text(str(year))
#       8     driver.find_element_by_xpath("//*[@class='submit button']").click()
# ----> 9     element = driver.find_element_by_link_text(str(player))
#      10     driver.execute_script("arguments[0].click();", element)
#      11     testsoup = BeautifulSoup(driver.page_source, "html.parser")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"Damion James"}
#   (Session info: chrome=81.0.4044.138)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.18363 x86_64)

# %%
df
# Out:
#           player_name                                              title  \
# 0       Blake Griffin                Rookie Retrospective: Blake Griffin
# 1       Blake Griffin               NBA Draft Media Day Video Interviews
# 2       Blake Griffin  Blake Griffin: I'm going to work to be a compl...
# 3       Blake Griffin  Situational Statistics: This Year's Power Forw...
# 4       Blake Griffin       NCAA Weekly Performers, 12/11/2008, Part One
# 5       Blake Griffin  Top NBA Draft Prospects in the Big 12 (Part On...
# 6       Blake Griffin  Bad News for Those Who Didnt Do Their Homewor...
# 7       Blake Griffin  Marquee Matchup: Michael Beasley vs. Blake Gri...
# 8       Blake Griffin          NCAA Weekly Performers, 1/3/08-- Part One
# 9       Blake Griffin  Nike Jordan All-American Classic: Main Event R...
# 10      Blake Griffin   Nike Jordan All-America Classic: Friday Practice
# 11      Blake Griffin     McDonald's All America Game Practices: Day Two
# 12  Terrence Williams  NBA Summer League Review 2010: Orlando Player ...
# 13  Terrence Williams               NBA Draft Media Day Video Interviews
# 14  Terrence Williams  NBA Draft Media Day Interview Transcripts (Par...
# 15  Terrence Williams          NBA Combine Media Availability Interviews
# 16  Terrence Williams  Situational Statistics: This Year's Shooting G...
# 17  Terrence Williams        NCAA/NIT Tournament Stock Watch, Rumor Mill
# 18  Terrence Williams                     NCAA Weekly Performers, 2/4/09
# 19  Terrence Williams  Top NBA Draft Prospects in the Big East (Part ...
# 20  Terrence Williams  Top NBA Draft Prospects in the Big East (Part ...
# 21  Terrence Williams  adidas Nations Basketball Experience Notebook ...
# 22  Terrence Williams  NCAA Tournament: Stock Watch (round of 32, Sat...
# 23  Terrence Williams                         Adidas Derby Classic Recap
# 24   Gerald Henderson          NBA Combine Media Availability Interviews
# 25   Gerald Henderson  Situational Statistics: This Year's Shooting G...
# 26   Gerald Henderson        NCAA/NIT Tournament Stock Watch, Rumor Mill
# 27   Gerald Henderson                    NCAA Weekly Performers, 1/29/09
# 28   Gerald Henderson  Top NBA Draft Prospects in the ACC (Part One: ...
# 29   Gerald Henderson  Top NBA Draft Prospects in the ACC (Part One: ...
# 30   Gerald Henderson                   2006 Nike Hoop Summit Game Recap
# 31   Gerald Henderson  2006 McDonald's All-American Game, individual ...
#
#                       date  early_than_draft_day  \
# 0   Dec 25, 2010, 05:56 pm                 False
# 1   Jun 25, 2009, 12:31 am                 False
# 2   May 22, 2009, 12:03 am                  True
# 3   Apr 23, 2009, 02:36 am                  True
# 4   Dec 11, 2008, 04:07 am                  True
# 5   Sep 02, 2008, 02:09 am                  True
# 6   Mar 26, 2008, 11:06 pm                  True
# 7   Jan 13, 2008, 05:39 pm                  True
# 8   Jan 04, 2008, 03:24 am                  True
# 9   May 01, 2007, 02:28 am                  True
# 10  Apr 21, 2007, 01:59 am                  True
# 11  Mar 27, 2007, 10:03 am                  True
# 12  Aug 10, 2010, 09:20 pm                 False
# 13  Jun 25, 2009, 12:31 am                 False
# 14  Jun 25, 2009, 12:15 am                 False
# 15  May 29, 2009, 08:31 pm                  True
# 16  Apr 27, 2009, 11:53 pm                  True
# 17  Mar 24, 2009, 04:47 pm                  True
# 18  Feb 04, 2009, 02:00 am                  True
# 19  Oct 22, 2008, 01:28 am                  True
# 20  Oct 20, 2007, 05:20 am                  True
# 21  Aug 08, 2007, 02:24 am                  True
# 22  Mar 18, 2007, 05:29 am                  True
# 23  Apr 19, 2005, 08:53 pm                  True
# 24  May 29, 2009, 08:31 pm                  True
# 25  Apr 27, 2009, 11:53 pm                  True
# 26  Mar 24, 2009, 04:47 pm                  True
# 27  Jan 29, 2009, 12:24 am                  True
# 28  Oct 04, 2008, 02:59 am                  True
# 29  Sep 26, 2007, 01:15 am                  True
# 30  Apr 10, 2006, 03:47 am                  True
# 31  Mar 30, 2006, 09:39 am                  True
#
#                                               context
# 0   Blake Griffin, 6-10, PF/C, Los Angeles Clipper...
# 1
# 2   Jonathan Givony: How have the last few weeks b...
# 3   \tBlake Griffin's spot at the top of draft is...
# 4   Although were always reluctant to read too mu...
# 5   Blake Griffin definitely exceeded expectations...
# 6   Griffin and #6 seed Oklahoma were blown out in...
# 7   Looking at Griffin, he has some notable questi...
# 8   Quietly having an excellent freshman season so...
# 9   Blake Griffin had a decent game, making do wit...
# 10  Griffin had a strong game here, making his pre...
# 11  Griffin used his absolutely remarkable body to...
# 12  Much like Jrue Holiday, Terrence Williams had ...
# 13
# 14  DraftExpress: Charlotte
# promise?Terrence Willi...
# 15
# 16  \tTerrence Williams looks like a pretty safe ...
# 17  Terrence Williams put on an unbelievable shoot...
# 18  Fresh off seeing their 9-game winning streak s...
# 19  The Louisville Cardinals will be without one o...
# 20  Entering the 07-08 season, Williams currently ...
# 21  The biggest story to emerge from the counselor...
# 22  Terrence Williams, playing in the final game o...
# 23  The first thing that stands out to fans is Ter...
# 24
# 25  Gerald Henderson is largely a mixed bag from ...
# 26  Gerald Henderson clearly wasnt ready to end h...
# 27  There may not be a hotter draft prospect anywh...
# 28  Gerald Henderson saved some of the best basket...
# 29  A McDonalds All-American coming out of high s...
# 30  Though he didnt play as well as he did during...
# 31  The most complete player on the floor tonight ...

# %%
df.to_csv('NBA Scouting Report 2009-2017.csv')
